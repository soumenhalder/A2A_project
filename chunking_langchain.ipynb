# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
document = PyPDFLoader(file_path='../0_Research_AStudyontheTransitionofOtt_OvertheTop_Se.pdf', extract_images=False).load()
text = " ".join([page.page_content for page in document])  # `page_content` contains the text
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_text(text)
print(texts[:5])
# Out:
# ['International Journal for Multidisciplinary Research (IJFMR) \n \nE-ISSN: 2582-2160   ●   Website: www.ijfmr.com       ●   Email: editor@ijfmr.com \n \nIJFMR23045954 Volume 5, Issue 4, July-August 2023 1 \n \nA Study on The Transition of Ott Over the Top \nServices Among Young Consumers Across \nChennai City \n \nDr. Nisha Guruharan1, Catherin Amala Rakkini U2 \n \n1Assistant Professor, Stella Maris College \n2Student, Stella Maris College \n \nABSTRACT:', '2Student, Stella Maris College \n \nABSTRACT: \nOTT also refers to a brand -new generation of contemporary television networks similar to traditional \nsatellite or cable TV providers . The objective of this study is to find the recent  transition of OTT services \namong young consumers . The study focuses on the factors influencing the young consumers in the OTT \nplatforms and also the strategies adopted by the company to attract them. A survey was conducted and', 'data from 100 respondents were collected across the young cons
# ...

# %%
texts[0]
# Out:
# 'International Journal for Multidisciplinary Research (IJFMR) \n \nE-ISSN: 2582-2160   ●   Website: www.ijfmr.com       ●   Email: editor@ijfmr.com \n \nIJFMR23045954 Volume 5, Issue 4, July-August 2023 1 \n \nA Study on The Transition of Ott Over the Top \nServices Among Young Consumers Across \nChennai City \n \nDr. Nisha Guruharan1, Catherin Amala Rakkini U2 \n \n1Assistant Professor, Stella Maris College \n2Student, Stella Maris College \n \nABSTRACT:'

# %%
texts[1]
# Out:
# '2Student, Stella Maris College \n \nABSTRACT: \nOTT also refers to a brand -new generation of contemporary television networks similar to traditional \nsatellite or cable TV providers . The objective of this study is to find the recent  transition of OTT services \namong young consumers . The study focuses on the factors influencing the young consumers in the OTT \nplatforms and also the strategies adopted by the company to attract them. A survey was conducted and'

# %%
texts[2]
# Out:
# 'data from 100 respondents were collected across the young consumers in Chennai. This study undergo es \ndescriptive and analytical analysis.The findings reveal that the factors such as recommendations, rate of \nadvertisement, quality of the content, audio and video quality, loading time influences the young \nconsumers in the OTT platforms .The reasons behin d paid and unpaid users of OTT services were also'

# %%
texts[3]
# Out:
# 'identified .The further study would help to infer the experiences of different users of OTT platforms and \ntheir views.  \n \nKeywords: OTT platforms , online , streaming , subscriber , audio , video, movies ,etc,.  \n \nINTRODUCTION \nThe Over -The-Top (OTT) media platform is an online platform that provides audiences with direct \naccess to digital media content. OTT avoids the businesses that formerly acted as a controller or'

# %%
texts[4]
# Out:
# 'distributor of this content, including cable, radio, and satel lite television channels. The younger \ngeneration is increasingly accepting of extravagant platforms. Over -the-top (OTT) services are widely \nused in both domestic and foreign markets. The term "New media as a change agent of Indian television \nand cinema" is often used to describe OTT services. There are many advantages that help OTT platforms \nbecome more popular and are used more frequently, including:'

# %%
for i, chunk in enumerate(texts[:100]):
    print(f"Chunk {i}:\n{chunk}\n{'-'*40}\n")
# Out:
# Chunk 0:
# International Journal for Multidisciplinary Research (IJFMR)
#
# E-ISSN: 2582-2160   ●   Website: www.ijfmr.com       ●   Email: editor@ijfmr.com
#
# IJFMR23045954 Volume 5, Issue 4, July-August 2023 1
#
# A Study on The Transition of Ott Over the Top
# Services Among Young Consumers Across
# Chennai City
#
# Dr. Nisha Guruharan1, Catherin Amala Rakkini U2
#
# 1Assistant Professor, Stella Maris College
# 2Student, Stella Maris College
#
# ABSTRACT:
# ----------------------------------------
#
# Chunk 1:
# 2Student, Stella Maris College
#
# ABSTRACT:
# OTT also refers to a brand -new generation of contemporary television networks similar to traditional
# satellite or cable TV providers . The objective of this study is to find the recent  transition of OTT services
# among young consumers . The study focuses on the factors influencing the young consumers in the OTT
# platforms and also the strategies adopted by the company to attract them. A survey was conducted and
# ...
